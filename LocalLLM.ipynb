# %% [markdown]
# ##Installing Dependencies
# - ollama to run llm locally
# - pyngrok to host model publically
# - python-dot-env to load .env file

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# !pip install pyngrok
# !pip install python-dotenv
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# ...

# %% [markdown]
# ## Setting up ngrok

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from pyngrok import ngrok

ngrok_auth_token = os.getenv("NGROK_AUTH_TOKEN")

ngrok.set_auth_token(ngrok_auth_token)

# %% [markdown]
# ## Defining function to run mutliple command in single thread

# %%
import asyncio


async def run_process(cmd):
  print('>>> starting', *cmd)
  p = await asyncio.subprocess.create_subprocess_exec(
      *cmd,
      stdout=asyncio.subprocess.PIPE,
      stderr=asyncio.subprocess.PIPE,
  )

  async def pipe(lines):
    async for line in lines:
      print(line.strip().decode('utf-8'))

  await asyncio.gather(
      pipe(p.stdout),
      pipe(p.stderr),
  )

# %% [markdown]
# ## Running and hosting LLAMA3

# %%
from IPython.display import clear_output
clear_output()
await asyncio.gather(
    run_process(['ollama', 'serve']),
    run_process(['ngrok', 'http', '11434', '--host-header=\"localhost:11434\"']),
    run_process(['ollama','pull','llama3']),
    run_process(['ollama','run','llama3'])
)
# Out:
# Streaming output truncated to the last 5000 lines.
# pulling 8ab4849b038c... 100% ▕████████████████▏  254 B
# pulling 577073ffcc6c...   0% ▕                ▏    0 B
# pulling 3f8eb4da87fa... 100% ▕████████████████▏  485 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6a0746a1ec1a... 100% ▕████████████████▏ 4.7 GB
# pulling 4fa551d4f938... 100% ▕████████████████▏  12 KB
# pulling 8ab4849b038c... 100% ▕████████████████▏  254 B
# pulling 577073ffcc6c...   0% ▕                ▏    0 B
# pulling 3f8eb4da87fa... 100% ▕████████████████▏  485 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6a0746a1ec1a...   0% ▕                ▏    0 B
# pulling 4fa551d4f938...   0% ▕                ▏    0 B
# pulling 8ab4849b038c...   0% ▕                ▏    0 B
# pulling 577073ffcc6c... 100% ▕████████████████▏  110 B
# pulling 3f8eb4da87fa...   0% ▕                ▏    0 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 6a0746a1ec1a...   0% ▕                ▏    0 B
# ...
